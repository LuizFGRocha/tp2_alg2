# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from util import read_real

# %%
p, l, k = read_real('real-instances/beans.dat')

scaler = StandardScaler()
scaled_p = scaler.fit_transform(p)

pca = PCA(n_components=3)

result = pca.fit_transform(scaled_p)

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(result[:,0], result[:,1], result[:,2], c=l)

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.2754426 , 0.50215406, 0.64364015])
